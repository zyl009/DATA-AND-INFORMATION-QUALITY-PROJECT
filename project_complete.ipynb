# %%
from google.colab import drive # Mounte personal Gdrive folder
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ###Install lib, import module and read data

# %%
# !pip install ydata-profiling
# !python -m spacy download en_core_web_lg
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 29.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 687.8/687.8 kB 28.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 83.6 MB/s eta 0:00:00
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27081 sha256=3afde51d869a291762b51d6c3aeb686546d69db2792bb7eb3cb5dd59dab422f6
#   Stored in directory: /root/.cache/pip/wheels/8d/55/1a/19cd535375ed1ede0c996405ebffe34b196d78e2d9545723a2
# Successfully built htmlmin
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 587.7/587.7 MB 2.2 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport
import numpy as np
from datetime import datetime
import re
import spacy

# Load the large English model
nlp = spacy.load('en_core_web_lg')

# %%
data = pd.read_csv('https://raw.githubusercontent.com/zyl009/DATA-AND-INFORMATION-QUALITY-PROJECT/refs/heads/main/attacks.csv')
data= pd.DataFrame(data)

# %% [markdown]
# ###DATA EXPLORATION

# %%
data
# Out:
#        Case Number                  Date    Year        Type  \
# 0       2017.06.11            2017-06-11  2017.0  Unprovoked
# 1     2017.06.10.b            2017-06-10  2017.0  Unprovoked
# 2     2017.06.10.a            2017-06-10  2017.0  Unprovoked
# 3     2017.06.07.R  Reported 07-Jun-2017  2017.0  Unprovoked
# 4       2017.06.04            2017-06-04  2017.0  Unprovoked
# ...            ...                   ...     ...         ...
# 6089       ND.0005           Before 1903     0.0  Unprovoked
# 6090       ND.0004           Before 1903     0.0  Unprovoked
# 6091       ND.0003             1900-1905     0.0  Unprovoked
# 6092       ND.0002             1883-1889     0.0  Unprovoked
# 6093       ND.0001             1845-1853     0.0  Unprovoked
#
#                  Country               Area  \
# 0              AUSTRALIA  Western Australia
# 1              AUSTRALIA           Victoria
# 2                    USA            Florida
# 3         UNITED KINGDOM        South Devon
# ...

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order'],
#       dtype='object')

# %%
data.shape
# Out:
# (6094, 22)

# %%
data.dtypes
# Out:
# Case Number                object
# Date                       object
# Year                      float64
# Type                       object
# Country                    object
# Area                       object
# Location                   object
# Activity                   object
# Name                       object
# Sex                        object
# Age                        object
# Injury                     object
# Fatal (Y/N)                object
# Time                       object
# Species                    object
# Investigator or Source     object
# pdf                        object
# href formula               object
# href                       object
# Case Number.1              object
# Case Number.2              object
# original order              int64
# dtype: object

# %%
data.describe()
# Out:
#               Year  original order
# count  6092.000000     6094.000000
# mean   1926.197308     3048.499672
# std     284.366422     1759.331064
# min       0.000000        2.000000
# 25%    1942.000000     1525.250000
# 50%    1976.000000     3048.500000
# 75%    2004.000000     4571.750000
# max    2017.000000     6095.000000

# %%
data.duplicated().any()
# Out:
# False

# %% [markdown]
# ###(1)PROFILING

# %%
PROFILE = ProfileReport(data, title="Pandas Profiling Report")
PROFILE.to_file("profiling.html")
PROFILE
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ###(2)DQ ASSESSMENT

# %%
for col in data.columns:
    print("DQ Assessment for "+col+":")

    DISTINCT = (data[col].nunique())
    COUNT = data[col].count()
    ROWS = len(data[col])
    UNIQUENESS = DISTINCT / ROWS
    print("UNIQUENESS: ", UNIQUENESS)

    DISTINCTNESS = DISTINCT / COUNT
    print("DISTINCTNESS: ", DISTINCTNESS)

    MAX_COUNTS = max(data[col].value_counts())
    CONSTANCY = MAX_COUNTS / COUNT
    print("CONSTANCY: ", CONSTANCY)

    COMPLETENESS = COUNT / ROWS
    print("COMPLETENESS: ", COMPLETENESS)

    print("\n\n")
# Out:
# DQ Assessment for Case Number:
# UNIQUENESS:  0.9973744666885461
# DISTINCTNESS:  0.9973744666885461
# CONSTANCY:  0.0003281916639317361
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Date:
# UNIQUENESS:  0.8528060387266163
# DISTINCTNESS:  0.8528060387266163
# CONSTANCY:  0.0018050541516245488
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Year:
# UNIQUENESS:  0.03938299967180833
# DISTINCTNESS:  0.03939592908732764
# CONSTANCY:  0.02314510833880499
# COMPLETENESS:  0.9996718083360683
#
#
#
# DQ Assessment for Type:
# UNIQUENESS:  0.0009845749917952085
# DISTINCTNESS:  0.0009852216748768472
# CONSTANCY:  0.7333333333333333
# COMPLETENESS:  0.9993436166721366
#
#
#
# DQ Assessment for Country:
# UNIQUENESS:  0.033475549721037084
# DISTINCTNESS:  0.03373015873015873
# CONSTANCY:  0.35714285714285715
# COMPLETENESS:  0.9924515917295701
#
#
#
# DQ Assessment for Area:
# UNIQUENESS:  0.13111256974072857
# DISTINCTNESS:  0.14061950017599437
# CONSTANCY:  0.1786342837029215
# ...

# %% [markdown]
# #(3) DATA CLEANING (DATA TRANSFORMATION)

# %%
# Remove leading/trailing spaces for every col, fill empty with nan
for col in data.columns:
    if data[col].dtype == 'object':  # Check if the column contains string data
        data[col] = data[col].str.strip()
        # Replace empty strings with NaN
        data[col] = data[col].replace("", np.nan)

# %%
#Remove specific symbols: @#$%^*�!? for every col
# function to clean special symbols
def remove_special_symbols(text):
    if pd.isna(text):  # Skip NaN values
        return text
    # Remove specific symbols: @#$%^*�!?
    text = re.sub(r'[#$%^*@�!?]', '', str(text))
    return text

# Apply cleaning to all object (text-based) columns
for col in data.select_dtypes(include=['object']).columns:
    data[col] = data[col].apply(remove_special_symbols)

# %% [markdown]
# ##case number column

# %%
data['Case Number'].equals(data['Case Number.1'].equals(data['Case Number.2']))
# Out:
# False

# %%
data['Case Number'].equals(data['Case Number.1'])
# Out:
# False

# %%
data['Case Number.1'].equals(data['Case Number.2'])
# Out:
# False

# %%
data['Case Number'].isin(data['Case Number.1']).value_counts()
# Out:
# Case Number
# True     6079
# False      15
# Name: count, dtype: int64

# %%
data['Case Number'].isin(data['Case Number.2']).value_counts()
# Out:
# Case Number
# True     6092
# False       2
# Name: count, dtype: int64

# %%
data['Case Number.1'].isin(data['Case Number.2']).value_counts()
# Out:
# Case Number.1
# True     6082
# False      12
# Name: count, dtype: int64

# %%
#since Case Number, Case NumberN.1 and Case Number N.2 are similar, and they are just the number of the case, delete the Case Number.1 and Case Number.2
data=data.drop(['Case Number.1','Case Number.2'],axis=1)

# %% [markdown]
# ##Date and Year and Time column

# %% [markdown]
# ###normalize the date

# %%
# Function to normalize date
def normalize_date(value):
    # Dictionary for month corrections and seasons mapping
    month_corrections = {
        "Jut": "Jul",
        "rch": "Mar",
        "ept": "Sep",
        "prr": "Apr",
        }
    seasons_mapping = {
        "Winter": "12-01",
        "Spring": "03-01",
        "Summer": "06-01",
        "Fall": "09-01",
    }

    # Correct common typos
    for typo, correct in month_corrections.items():
        value = value.replace(typo, correct)

    # Patterns
    season_year_pattern = r'(Winter|Spring|Summer|Fall)[^\d]*(\d{4})'  # e.g., Winter 1942
    day_month_year_pattern = r'(\d{1,2})-([A-Za-z]{3})-(\d{4})'  # e.g., 19-Jul-1913
    month_year_pattern = r'([A-Za-z]{3})-(\d{4})'  # e.g., Aug-1987
    year_pattern = r'(\d{4})'  # e.g., 1901

    try:
       # Handle YYYY-MM-DD (already formatted)
        if re.match(r'^\d{4}-\d{2}-\d{2}$', value):
            return value
        # Check if the value matches the format 'YYYY.MM.DD'
        match = re.match(r'^(\d{4})\.(\d{2})\.(\d{2})$', value)
        if match:
            year, month, day = match.groups()
            # Replace invalid month/day components
            month = '01' if month == '00' else month
            day = '01' if day == '00' else day
            return f"{year}-{month}-{day}"  # Return in 'YYYY-MM-DD' format
        # Match season and year
        match = re.search(season_year_pattern, value, re.IGNORECASE)
        if match:
            season, year = match.groups()
            month_day = seasons_mapping[season.capitalize()]
            return f"{year}-{month_day}"
        # Handle phrases like 'mid-1870s'
        if "mid" in value:
            match = re.search(r'(\d{4})', value)
            if match:
                year = match.group(1)
                return f"{year}-06-01"  # Approximate mid-year date

        # Match day-month-year
        match = re.search(day_month_year_pattern, value)
        if match:
            day, month, year = match.groups()
            month_num = datetime.strptime(month, "%b").month
            return f"{year}-{month_num:02d}-{int(day):02d}"

        # Match month-year
        match = re.search(month_year_pattern, value)
        if match:
            month, year = match.groups()
            month_num = datetime.strptime(month, "%b").month
            return f"{year}-{month_num:02d}-01"

        # Match year only
        match = re.search(year_pattern, value)
        if match:
            year = match.group(1)
            return f"{year}-01-01"

    except Exception as e:
        # Log unexpected errors for debugging
        print(f"Error processing value: {value}. Error: {e}")

    # Return None for unprocessable rows
    return np.nan

# %%
# Example DataFrame
sampledata = pd.DataFrame({
    'Date': [
        '1986-01-02','2008.01.30','No date (3 days after preceding incident) & prior to 19-Jul-1913','Before 1903','Reported 09-Aprr-1855',
        'No date, Before Aug-1987', '1950s', '2003?', 'Ca. 1543','Circa 500 A.D.', 'Ca. 336.B.C.', 'Before Feb-1998', '190Feb-2010',
        'During the war 1943-1945','Summer-2008','25-Jut-1881','Reported 30-March-1878','Ca. mid-1870s','Reported 03-Sept-1816','Fall 1943','early winter 1993'
    ]
})

# Apply the function to the Date column
sampledata['Normalized Date'] = sampledata['Date'].apply(normalize_date)

# Display the updated DataFrame
sampledata
# Out:
#                                                  Date Normalized Date
# 0                                          1986-01-02      1986-01-02
# 1                                          2008.01.30      2008-01-30
# 2   No date (3 days after preceding incident) & pr...      1913-07-19
# 3                                         Before 1903      1903-01-01
# 4                               Reported 09-Aprr-1855      1855-04-01
# 5                            No date, Before Aug-1987      1987-08-01
# 6                                               1950s      1950-01-01
# 7                                               2003?      2003-01-01
# 8                                            Ca. 1543      1543-01-01
# 9                                      Circa 500 A.D.             NaN
# 10                                       Ca. 336.B.C.             NaN
# 11                                    Before Feb-1998      1998-02-01
# ...

# %%
# Apply the function to the Date column
data['Date'] = data['Date'].apply(normalize_date)

# %%
# Convert Date column to datetime
data['Date']= pd.to_datetime(data['Date'],format='%Y-%m-%d',errors='coerce')

# %%
data
# Out:
#        Case Number       Date    Year        Type             Country  \
# 0       2017.06.11 2017-06-11  2017.0  Unprovoked           AUSTRALIA
# 1     2017.06.10.b 2017-06-10  2017.0  Unprovoked           AUSTRALIA
# 2     2017.06.10.a 2017-06-10  2017.0  Unprovoked                 USA
# 3     2017.06.07.R 2017-06-07  2017.0  Unprovoked      UNITED KINGDOM
# 4       2017.06.04 2017-06-04  2017.0  Unprovoked                 USA
# ...            ...        ...     ...         ...                 ...
# 6089       ND.0005 1903-01-01     0.0  Unprovoked           AUSTRALIA
# 6090       ND.0004 1903-01-01     0.0  Unprovoked           AUSTRALIA
# 6091       ND.0003 1900-01-01     0.0  Unprovoked                 USA
# 6092       ND.0002 1883-01-01     0.0  Unprovoked              PANAMA
# 6093       ND.0001 1845-01-01     0.0  Unprovoked  CEYLON (SRI LANKA)
#
#                    Area                                         Location  \
# ...

# %%
# Convert the 'Year' column to integers (handling invalid or non-numeric values)
data['Year'] = pd.to_numeric(data['Year'], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# ###Time

# %%
#move Time column next to the Date column
Time_to_move = data.pop('Time')  # Remove the column
data.insert(2, 'Time', Time_to_move)

# %%
data['Time'].isnull().sum()
# Out:
# 3250

# %%
# Function to normalize time
def normalize_time(value):
    # Ensure the value is a string
    if not isinstance(value, str):
        return np.nan
    # Regex to find time already in HH:MM format
    match = re.search(r'\b(\d{1,2}):(\d{2})\b', value)
    if match:
        hour, minute = match.groups()
        return f"{int(hour):02d}:{int(minute):02d}"  # Return valid HH:MM format

    # Regex to find valid time patterns like hh:mm or hhm
    match = re.search(r'(\d{1,2})h(\d{2})', value)
    if match:
        hour, minute = match.groups()
        return f"{int(hour):02d}:{int(minute):02d}"

    # Map descriptions to approximate times
    time_map = {
        'early morning': '06:00',
        'late morning': '10:30',
        'morning': '08:00',
        'early afternoon': '13:00',
        'late afternoon': '16:30',
        'afternoon': '15:00',
        'late evening': '21:00',
        'evening': '19:00',
        'dusk': '18:30',
        'night': '22:00',
        'noon': '12:00',
        'midnight': '00:00'
      }
    for key, mapped_time in time_map.items():
        if key in value.lower():
            return mapped_time


    # Return None for unprocessable rows
    return np.nan


# Sample data
sampledTime = pd.DataFrame({
    'Time': ['08h00', 'wwwda15h00bdbgrfd', '15h45lll', 'Dusk','dusklllll', 'morning', 'MORNING','late late Late morning', 'siskks early afternoon', 'kcdoak night 6154', 'unknown']
})

# Apply normalization
sampledTime['Normalized Time'] = sampledTime['Time'].apply(normalize_time)
sampledTime
# Out:
#                       Time Normalized Time
# 0                    08h00           08:00
# 1        wwwda15h00bdbgrfd           15:00
# 2                 15h45lll           15:45
# 3                     Dusk           18:30
# 4                dusklllll           18:30
# 5                  morning           08:00
# 6                  MORNING           08:00
# 7   late late Late morning           10:30
# 8   siskks early afternoon           13:00
# 9        kcdoak night 6154           22:00
# 10                 unknown             NaN

# %%
data['Time']=data['Time'].apply(normalize_time)

# %%
data['Time']=pd.to_datetime(data['Time'],format='%H:%M',errors='coerce').dt.time

# %%
data
# Out:
#        Case Number       Date      Time  Year        Type             Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017  Unprovoked           AUSTRALIA
# 1     2017.06.10.b 2017-06-10  15:45:00  2017  Unprovoked           AUSTRALIA
# 2     2017.06.10.a 2017-06-10  10:00:00  2017  Unprovoked                 USA
# 3     2017.06.07.R 2017-06-07       NaT  2017  Unprovoked      UNITED KINGDOM
# 4       2017.06.04 2017-06-04       NaT  2017  Unprovoked                 USA
# ...            ...        ...       ...   ...         ...                 ...
# 6089       ND.0005 1903-01-01       NaT     0  Unprovoked           AUSTRALIA
# 6090       ND.0004 1903-01-01       NaT     0  Unprovoked           AUSTRALIA
# 6091       ND.0003 1900-01-01       NaT     0  Unprovoked                 USA
# 6092       ND.0002 1883-01-01       NaT     0  Unprovoked              PANAMA
# 6093       ND.0001 1845-01-01       NaT     0  Unprovoked  CEYLON (SRI LANKA)
#
# ...

# %% [markdown]
# ##Country, Area and Location column

# %% [markdown]
# ###COUNTRY

# %%
#Only one country (in the strings with '/' we will take only the first country)
#bring all the characters in uppercase
data["Country"] = data['Country'].str.title()
#adopt some convention in countries names (the country/country format I assume to be valid)
data.loc[data['Country'] == 'England', 'Country'] = 'United Kingdom'
data.loc[data['Country'] == 'Scotland', 'Country'] = 'United Kingdom'
data.loc[data['Country'] == 'Between Portugal & India', 'Country'] = 'Portugal / India'
data.loc[data['Country'] == 'Ceylon (Sri Lanka)', 'Country'] = 'Sri Lanka'

data[["Country","Country2"]] = data["Country"].str.split("/", expand = True)
data.drop("Country2", axis=1, inplace=True)

# %% [markdown]
# ###AREA

# %%
#Title string,illegible characters eliminated,No km/miles and so on, we take only the part of the string that contain the Area name

def standardize_area(area):
    if(pd.isna(area)):
      return np.nan

    # Remove numbers and "miles", "km", etc. (e.g., "16 miles off Hilton Head" -> "Hilton Head")
    area = re.sub(r'\d+\s*(miles|km|ft|yards|m)', '', area, flags=re.IGNORECASE)

    # Remove unnecessary punctuation or special characters (keep only letters, spaces, hyphens, apostrophes)
    area = re.sub(r'[^A-Za-z\s\'-,]', '', area)

    # Normalize spaces (replace multiple spaces with a single space)
    area = re.sub(r'\s+', ' ', area).strip()

    # Capitalize the first letter of each word (e.g., "new york" -> "New York")
    area = area.title()


    return area

# %%
data['Area'] = data['Area'].apply(standardize_area)
data.loc[data['Area'] == '', 'Area'] = np.nan

# %% [markdown]
# ###LOCATION

# %%
def standardize_location(location):
    if(pd.isna(location)):
      return np.nan

    # Remove 'OFF', 'off', 'oFF', or 'Off' at the start of the 'Location' value
    location = re.sub(r'(?i)^\s*OFF', '', location)

    # Remove unnecessary punctuation or special characters (keep only letters, spaces, hyphens, apostrophes)
    location = re.sub(r'[^A-Za-z\s\'-,]', '', location)

    # Normalize spaces (replace multiple spaces with a single space)
    location = re.sub(r'\s+', ' ', location).strip()

    # Capitalize the first letter of each word (e.g., "new york" -> "New York")
    location = location.title()

    return location

# %%
data['Location'] = data['Location'].apply(standardize_location)
data.loc[data['Location'] == '', 'Location'] = np.nan

# %%
data['Location']
# Out:
# 0                              Point Casuarina, Bunbury
# 1                         Flinders, Mornington Penisula
# 2                           Ponce Inlet, Volusia County
# 3                                         Bantham Beach
# 4       Middle Sambo Reef Off Boca Chica, Monroe County
#                              ...
# 6089                                        Roebuck Bay
# 6090                                                NaN
# 6091                                     Ocracoke Inlet
# 6092                                    Panama Bay N, W
# 6093                Below The English Fort, Trincomalee
# Name: Location, Length: 6094, dtype: object

# %% [markdown]
# ##href column

# %%
data['href formula'].equals(data['href'])
# Out:
# False

# %%
data['href formula'].isin(data['href']).value_counts()
# Out:
# href formula
# True     6040
# False      54
# Name: count, dtype: int64

# %%
data.loc[data['href formula'] != data['href'], ['href formula', 'href']]
# Out:
#                                            href formula  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# 35    http://sharkattackfile.net/spreadsheets/pdf_di...
# 99    http://sharkattackfile.net/spreadsheets/pdf_di...
# 106   http://sharkattackfile.net/spreadsheets/pdf_di...
# 141   http://sharkattackfile.net/spreadsheets/pdf_di...
# 187   http://sharkattackfile.net/spreadsheets/pdf_di...
# 194   http://sharkattackfile.net/spreadsheets/pdf_di...
# 214   http://sharkattackfile.net/spreadsheets/pdf_di...
# 261   http://sharkattackfile.net/spreadsheets/pdf_di...
# 313   http://sharkattackfile.net/spreadsheets/pdf_di...
# 344   http://sharkattackfile.net/spreadsheets/pdf_di...
# 345   http://sharkattackfile.net/spreadsheets/pdf_di...
# 346   http://sharkattackfile.net/spreadsheets/pdf_di...
# 353   http://sharkattackfile.net/spreadsheets/pdf_di...
# 354   http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %%
#replace with correct value in href
data.loc[531,'href formula']=data['href'][531]
data.loc[3103,'href formula']=data['href'][3103]
data.loc[3104,'href formula']=data['href'][3104]

# %%
#find rows where the 'href formular' column does not start with 'http'
invalid_urls = data[~data['href formula'].str.startswith('http', na=False)]
# Display rows with invalid URLs
invalid_urls
# Out:
#      Case Number       Date Time  Year        Type  Country            Area  \
# 6008     ND.0100 2003-01-01  NaT     0  Unprovoked  Bahamas  Andros Islands
#
#              Location      Activity         Name Sex   Age           Injury  \
# 6008  Great Guana Cay  Spearfishing  C.D. Dollar    M  NaN  Swim fin bitten
#
#      Fatal (Y/N)          Species  Investigator or Source  \
# 6008           N  1.8 m [6'] shark       R.D. Weeks, GSAF
#
#                        pdf                                       href formula  \
# 6008  ND-0100-CDDollar.pdf  Q93http://sharkattackfile.net/spreadsheets/pdf...
#
#                                                    href  original order
# 6008  Q93http://sharkattackfile.net/spreadsheets/pdf...              87

# %%
data.loc[6008,'href formula']=data.loc[6008,'href formula'].lstrip('Q93')
data.loc[6008,'href formula']
# Out:
# 'http://sharkattackfile.net/spreadsheets/pdf_directory/ND-0100-CDDollar.pdf'

# %%
#delete href column since it is similar with href formula, and href fomula is more clean
del(data['href'])

# %%
#rename href formula with href
data.rename(columns={'href formula': 'href'}, inplace=True)

# %% [markdown]
# ###Original order column

# %%
#Deleted the column 'original order' as it was uniformly distributed, not useful
del(data['original order'])

# %%
data
# Out:
#        Case Number       Date      Time  Year        Type         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017  Unprovoked       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017  Unprovoked       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017  Unprovoked             Usa
# 3     2017.06.07.R 2017-06-07       NaT  2017  Unprovoked  United Kingdom
# 4       2017.06.04 2017-06-04       NaT  2017  Unprovoked             Usa
# ...            ...        ...       ...   ...         ...             ...
# 6089       ND.0005 1903-01-01       NaT     0  Unprovoked       Australia
# 6090       ND.0004 1903-01-01       NaT     0  Unprovoked       Australia
# 6091       ND.0003 1900-01-01       NaT     0  Unprovoked             Usa
# 6092       ND.0002 1883-01-01       NaT     0  Unprovoked          Panama
# 6093       ND.0001 1845-01-01       NaT     0  Unprovoked       Sri Lanka
#
#                    Area                                         Location  \
# ...

# %% [markdown]
# ##Type and Activity column

# %%
data['Type'].unique()
# Out:
# array(['Unprovoked', 'Provoked', nan, 'Invalid', 'Boat', 'Sea Disaster',
#        'Boating'], dtype=object)

# %%
#Type is related to the activity,  move 'Type' column next to the Activity column
Type_to_move = data.pop('Type')  # Remove the column
data.insert(7, 'Type', Type_to_move)

# %%
data.insert(9,'Activity Detail',data['Activity'])

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07       NaT  2017  United Kingdom
# 4       2017.06.04 2017-06-04       NaT  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01       NaT     0       Australia
# 6090       ND.0004 1903-01-01       NaT     0       Australia
# 6091       ND.0003 1900-01-01       NaT     0             Usa
# 6092       ND.0002 1883-01-01       NaT     0          Panama
# 6093       ND.0001 1845-01-01       NaT     0       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %%
data['Activity'].unique()
# Out:
# array(['Body boarding', 'Surfing', 'Spearfishing', ...,
#        'Crew swimming alongside their anchored ship',
#        '4 men were bathing', 'Wreck of  large double sailing canoe'],
#       dtype=object)

# %%
#main activity are swimming, Diving,surfing，boarding, fishing, Wading，Walking,Standing，Snorkeling，Bathing and Other
# Update the Activity column based on conditions
data['Activity'] = np.where(
    data['Activity'].str.contains('Swimming', case=False, na=False), 'Swimming',
    np.where(
        data['Activity'].str.contains('Diving', case=False, na=False), 'Diving',
        np.where(
        data['Activity'].str.contains('Surfing', case=False, na=False), 'Surfing',
        np.where(
        data['Activity'].str.contains('Boarding', case=False, na=False), 'Boarding',
        np.where(
        data['Activity'].str.contains('Fishing', case=False, na=False), 'Fishing',
        np.where(
        data['Activity'].str.contains('Wading', case=False, na=False), 'Wading',
        np.where(
        data['Activity'].str.contains('Walking', case=False, na=False), 'Walking',
        np.where(
        data['Activity'].str.contains('Standing', case=False, na=False), 'Standing',
        np.where(
        data['Activity'].str.contains('Snorkeling', case=False, na=False), 'Snorkeling',
        np.where(
        data['Activity'].str.contains('Bathing', case=False, na=False), 'Bathing',
        'Other'
))))))))))

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07       NaT  2017  United Kingdom
# 4       2017.06.04 2017-06-04       NaT  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01       NaT     0       Australia
# 6090       ND.0004 1903-01-01       NaT     0       Australia
# 6091       ND.0003 1900-01-01       NaT     0             Usa
# 6092       ND.0002 1883-01-01       NaT     0          Panama
# 6093       ND.0001 1845-01-01       NaT     0       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %%
#set No detail in Activity Detail column when data is the same in Activity and Activity Detail column
data.loc[data['Activity Detail'].str.lower()==data['Activity'].str.lower(),'Activity Detail']='No detail'

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07       NaT  2017  United Kingdom
# 4       2017.06.04 2017-06-04       NaT  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01       NaT     0       Australia
# 6090       ND.0004 1903-01-01       NaT     0       Australia
# 6091       ND.0003 1900-01-01       NaT     0             Usa
# 6092       ND.0002 1883-01-01       NaT     0          Panama
# 6093       ND.0001 1845-01-01       NaT     0       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %%
data['Type'].unique()
# Out:
# array(['Unprovoked', 'Provoked', nan, 'Invalid', 'Boat', 'Sea Disaster',
#        'Boating'], dtype=object)

# %%
data.loc[data['Type']=='Invalid',['Type','Activity','Activity Detail']]
# Out:
#          Type  Activity Activity Detail
# 12    Invalid   Surfing       No detail
# 18    Invalid     Other     Photo shoot
# 20    Invalid  Swimming       No detail
# 26    Invalid    Diving    Scuba Diving
# 52    Invalid   Fishing    Spearfishing
# ...       ...       ...             ...
# 5941  Invalid   Bathing       No detail
# 5951  Invalid     Other             NaN
# 5957  Invalid     Other  Went overboard
# 6019  Invalid    Diving    Scuba diving
# 6024  Invalid    Diving       No detail
#
# [529 rows x 3 columns]

# %%
data.loc[data['Type']=='Boat',['Type','Activity','Activity Detail']]
# Out:
#       Type Activity                        Activity Detail
# 44    Boat  Fishing                          Kayak fishing
# 45    Boat    Other                         Tagging sharks
# 83    Boat  Fishing                              No detail
# 101   Boat    Other                               Kayaking
# 108   Boat  Fishing  Fishing in Alabama Deep Fishing Rodeo
# ...    ...      ...                                    ...
# 5925  Boat    Other                                    NaN
# 5932  Boat  Fishing                              No detail
# 5939  Boat    Other                                    NaN
# 6004  Boat  Fishing                              No detail
# 6066  Boat  Fishing                    Wooden fishing boat
#
# [202 rows x 3 columns]

# %%
data.loc[data['Type']=='Boating',['Type','Activity','Activity Detail']]
# Out:
#          Type  Activity                                    Activity Detail
# 4109  Boating   Fishing                                   Longling fishing
# 4111  Boating   Fishing                                          No detail
# 4114  Boating     Other                                            Boating
# 4131  Boating     Other                                       Ocean racing
# 4132  Boating   Fishing                                Fishing for pompano
# ...       ...       ...                                                ...
# 5715  Boating   Fishing                                          No detail
# 5720  Boating   Fishing                                          No detail
# 5722  Boating     Other  Fleet of canoes caught by a squall and charged...
# 5765  Boating   Fishing                                          No detail
# 5766  Boating  Boarding                                    Boarding a ship
#
# [110 rows x 3 columns]

# %%
data.loc[data['Type']=='Sea Disaster',['Type','Activity','Activity Detail']]
# Out:
#               Type  Activity                               Activity Detail
# 325   Sea Disaster     Other                                           NaN
# 448   Sea Disaster     Other                                  Sea disaster
# 751   Sea Disaster     Other                                  Sea disaster
# 1018  Sea Disaster     Other                                  Air Disaster
# 1049  Sea Disaster     Other          Sinking of the cargo ship Mark Jason
# ...            ...       ...                                           ...
# 5973  Sea Disaster     Other                                           NaN
# 6051  Sea Disaster     Other    A group of survivors on a raft for 17-days
# 6061  Sea Disaster     Other                                           NaN
# 6063  Sea Disaster     Other                        Spent 8 days in dinghy
# 6064  Sea Disaster  Swimming  Aircraft ditched in the sea, swimming ashore
#
# [220 rows x 3 columns]

# %%
#set boat as boating
data.loc[data['Type']=='Boat','Type']='Boating'

# %%
# Update 'Activity' where 'Activity' is 'Other' and 'Type' is 'Boating' or 'Sea Distaster'
data.loc[(data['Activity'] == 'Other') & (data['Type'] == 'Boating'), 'Activity'] = 'Boating'
data.loc[(data['Activity'] == 'Other') & (data['Type'] =='Sea Disaster'),'Activity']='Sea Disaster'
#set No detail in Activity Detail column when data is the same in Activity and Activity Detail column
data.loc[data['Activity Detail'].str.lower()==data['Activity'].str.lower(),'Activity Detail']='No detail'

# %%
#set Invalid, Boating and sea disaster as Unknown
data.loc[data['Type']=='Invalid','Type']='Unknown'
data.loc[data['Type']=='Boating','Type']='Unknown'
data.loc[data['Type']=='Sea Disaster','Type']='Unknown'
data['Type'].unique()
# Out:
# array(['Unprovoked', 'Provoked', nan, 'Unknown'], dtype=object)

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07       NaT  2017  United Kingdom
# 4       2017.06.04 2017-06-04       NaT  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01       NaT     0       Australia
# 6090       ND.0004 1903-01-01       NaT     0       Australia
# 6091       ND.0003 1900-01-01       NaT     0             Usa
# 6092       ND.0002 1883-01-01       NaT     0          Panama
# 6093       ND.0001 1845-01-01       NaT     0       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %% [markdown]
# ##Name, Sex and Age

# %% [markdown]
# ###Name and Sex

# %%
#Reomve illeggible characters
data["Name"] = data["Name"].apply(
    lambda s: re.sub(r'[^\x00-\x7F]+', '', str(s)) if not pd.isna(s) else s
)

# %%
data.loc[data['Name'] == 'male', 'Name'] = 'M'
data.loc[data['Name'] == 'boy', 'Name'] = 'M'
data.loc[data['Name'] == 'female', 'Name'] = 'F'
data.loc[data['Name'] == 'girl', 'Name'] = 'F'

# %%
data.rename(columns={'Sex ': 'Sex'}, inplace=True)

# %%
data.loc[(data['Name'] == 'M')&(data['Sex'].isna()), 'Sex']
# Out:
# 2084    NaN
# 2908    NaN
# 3152    NaN
# 4196    NaN
# 4325    NaN
# 5104    NaN
# 5870    NaN
# 5919    NaN
# 5967    NaN
# Name: Sex, dtype: object

# %%
data.loc[(data['Name'] == 'F')&(data['Sex'].isna()), 'Sex']
# Out:
# Series([], Name: Sex, dtype: object)

# %%
data.loc[(data['Name'] == 'M')&(data['Sex'].isna()), 'Sex']='M'

# %%
data.loc[data['Name'] == 'F', 'Name'] = np.nan
data.loc[data['Name'] == 'M', 'Name'] = np.nan
data["Name"] = data["Name"].str.title()

# %%
##Using Spacy for identifying which are true names
def extract_name(name):
    if pd.isna(name):
        return np.nan
    doc = nlp(str(name))
    for ent in doc.ents:
        if ent.label_ == "PERSON":
            return ent.text
    return np.nan

data["Name"] = data["Name"].apply(extract_name)

# %%
data["Sex"].unique()
# Out:
# array(['M', 'F', nan, 'lli', 'N', '.'], dtype=object)

# %%
data.loc[data['Sex'] == 'lli', 'Sex'] = np.nan
data.loc[data['Sex'] == 'N', 'Sex'] = np.nan
data.loc[data['Sex'] == '.', 'Sex'] = np.nan
data["Sex"].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %% [markdown]
# ###AGE

# %%
print(data["Age"].dtype)
data["Age"]
# Out:
# object
# 0        48
# 1       NaN
# 2        19
# 3        30
# 4       NaN
#        ...
# 6089    NaN
# 6090    NaN
# 6091    NaN
# 6092    NaN
# 6093     15
# Name: Age, Length: 6094, dtype: object

# %%
#delete 's' in tail of strings to normalize some ages (ex: 20s -> 20) and also I put 'Teen' in a established age of 18
data['Age'] = data['Age'].str.capitalize()
data['Age'] = data['Age'].str.strip("s")
data.loc[data['Age'] == 'Teen', 'Age'] = "18"

# %%
#  Only one number is allowed，In case of more than one number I choose the first one
def standardize_age(age):
    if(pd.isna(age)):
      return np.nan
    pattern = r'\d+'
    match = re.search(pattern, age)
    if match:
        return match.group()
    return np.nan

# %%
data["Age"] = data["Age"].apply(standardize_age)

# %% [markdown]
# ##Injury and Fatal column

# %%
data['Injury'].nunique()
# Out:
# 3576

# %%
# Remove 'PROVOKED INCIDENT' and the associated comma (if present)
data['Injury'] = data['Injury'].str.replace(r'(\s*,\s*)?PROVOKED INCIDENT(\s*,\s*)?', '', regex=True).str.strip()
data['Injury'] = data['Injury'].str.replace(r'(\s*,\s*)?FATAL(\s*,\s*)?', '', regex=True).str.strip()

# %%
data['Fatal (Y/N)'].unique()
# Out:
# array(['N', 'Y', nan, 'UNKNOWN', '2017', 'F', 'VALUE', 'n'], dtype=object)

# %%
data.rename(columns={'Fatal (Y/N)': 'Fatal'}, inplace=True)

# %%
data.loc[data['Fatal']=='2017',['Injury','Fatal']]
# Out:
#                                        Injury Fatal
# 646  Lower left leg injured PROVOKED ACCIDENT  2017

# %%
data.loc[data['Fatal']=='F',['Injury','Fatal']]
# Out:
#                           Injury Fatal
# 4779  human remains washed ahore     F

# %%
data.loc[data['Fatal']=='VALUE',['Injury','Fatal']]
# Out:
#                                                  Injury  Fatal
# 5548  Forensic evidence indicated death resulted fro...  VALUE

# %%
data.loc[data['Fatal']=='n',['Injury','Fatal']]
# Out:
#                   Injury Fatal
# 5870  Lacerations to leg     n

# %%
data.loc[data['Fatal']=='N','Fatal']= 'NO'
data.loc[data['Fatal']=='Y','Fatal']= 'YES'
data.loc[data['Fatal']=='2017','Fatal']= 'NO'
data.loc[data['Fatal']=='F','Fatal']='YES'
data.loc[data['Fatal']=='VALUE','Fatal']='NO'
data.loc[data['Fatal']=='n','Fatal']='NO'

# %%
data['Fatal'].unique()
# Out:
# array(['NO', 'YES', nan, 'UNKNOWN'], dtype=object)

# %% [markdown]
# ##SPECIES

# %%
data.rename(columns={'Species ': 'Species'}, inplace=True)

# %%
#Split between Species and Size，identify the size of a shark and cast it into meters
def extract_size(s):
  s = str(s)

  match_float = re.search(r'\d+\.\d+', s)
  match_int = re.search(r'\d+', s)

  feet = False

  if '\'' in s:
    feet = True

# Check if a match is found
  if match_float:
    extracted_float = float(match_float.group())
    if feet:
      extracted_float *= 0.3048
    return extracted_float
  elif match_int:
    extracted_int = int(match_int.group())
    if feet:
      extracted_int *= 0.3048
    return extracted_int
  return np.nan

# %%
data['Size[m]'] = data['Species'].apply(extract_size)
data['Size[m]']
# Out:
# 0       4.0000
# 1       7.0000
# 2          NaN
# 3       3.0000
# 4       2.4384
#          ...
# 6089       NaN
# 6090       NaN
# 6091       NaN
# 6092       NaN
# 6093       NaN
# Name: Size[m], Length: 6094, dtype: float64

# %%
#move 'size[m]' column next to the species column
size_to_move = data.pop('Size[m]')  # Remove the column
data.insert(16, 'Size[m]', size_to_move)

# %%
#Load a good database containining a lot of possible species, and matching between what there is into the string
shark_species = pd.read_csv('/content/drive/MyDrive/DQ/project/shark_species.csv')
shark_species["SPECIES"] = shark_species["SPECIES"].str.strip()
shark_species["SPECIES"] = shark_species["SPECIES"].str.title()
shark_species
# Out:
#           SPECIES
# 0        Blacktip
# 1            Blue
# 2           Brown
# 3            Bull
# 4       Caribbean
# 5          Bronze
# 6           Dusky
# 7       Galapagos
# 8      Hammerhead
# 9            Grey
# 10          Lemon
# 11        Leopard
# 12       Whitetip
# 13      Sharpnose
# 14        Oceanic
# 15        Pacific
# 16         Pyjama
# 17          Tiger
# 18     Sharptooth
# 19          Silky
# 20      Silvertip
# 21    Smoothhound
# 22        Spinner
# 23           Horn
# 24      Bluntnose
# 25      Broadnose
# 26        Frilled
# 27        Basking
# 28         Bigeye
# 29      Crocodile
# 30         Goblin
# 31        Longfin
# 32      Megamouth
# 33      Porbeagle
# 34         Salmon
# 35       Shortfin
# 36          White
# 37       Bluegrey
# 38      Epaulette
# 39          Nurse
# 40        Spotted
# 41          Tawny
# 42          Whale
# 43   Whitespotted
# 44          Zebra
# 45       Sawshark
# 46        Bramble
# 47   Cookiecutter
# 48   Lanternshark
# ...

# %%
for i, s in enumerate(data["Species"]):
    s = str(s)
    s = s.title()
    matching_element = set(shark_species["SPECIES"]).intersection(s.split())
    if matching_element:
        data.loc[i, "Species"] = matching_element.pop()
    else:
        data.loc[i, "Species"] = np.nan

# %% [markdown]
# ##INVESTIGATOR

# %%
data["Investigator or Source"]
# Out:
# 0                         WA Today, 6/11/2017
# 1                                         NaN
# 2       Daytona Beach News-Journal, 6/10/2017
# 3                              C. Moore, GSAF
# 4                         Nine News, 6/7/2017
#                         ...
# 6089         H. Taunton; N. Bartlett,  p. 234
# 6090    H. Taunton; N. Bartlett,  pp. 233-234
# 6091     F. Schwartz, p.23; C. Creswell, GSAF
# 6092                      The Sun, 10/20/1938
# 6093                               S.W. Baker
# Name: Investigator or Source, Length: 6094, dtype: object

# %%
data["Investigator or Source"] = data["Investigator or Source"].str.replace(";",",")

# %%
def standardize_investigator(investigator):
    if(pd.isna(investigator)):
      return np.nan
    investigator = re.sub(r'\b\d{1,2}[-/]\d{1,2}[-/]\d{4}\b', '', investigator)
    investigator = investigator.title()
    investigator = re.sub(r'\b(Pp?\. ?\d{1,}(-\d{1,})?)\b', '', investigator)

    return investigator


data["Investigator or Source"] = data["Investigator or Source"].apply(standardize_investigator)
data['Investigator or Source'] = data['Investigator or Source'].str.replace(r', ?,', ',', regex=True)
data["Investigator or Source"] = data['Investigator or Source'].str.strip(" ,")
data["Investigator or Source"]
# Out:
# 0                             Wa Today
# 1                                  NaN
# 2           Daytona Beach News-Journal
# 3                       C. Moore, Gsaf
# 4                            Nine News
#                      ...
# 6089           H. Taunton, N. Bartlett
# 6090           H. Taunton, N. Bartlett
# 6091    F. Schwartz, C. Creswell, Gsaf
# 6092                           The Sun
# 6093                        S.W. Baker
# Name: Investigator or Source, Length: 6094, dtype: object

# %% [markdown]
# ##pdf

# %%
data["pdf"]
# Out:
# 0                  2017.06.11-Goff.pdf
# 1            2017.06.10.b-Flinders.pdf
# 2               2017.06.10.a-Brock.pdf
# 3             2017.06.07.R-Thomson.pdf
# 4               2017.06.04-Simpson.pdf
#                      ...
# 6089            ND-0005-RoebuckBay.pdf
# 6090                 ND-0004-Ahmun.pdf
# 6091    ND-0003-Ocracoke_1900-1905.pdf
# 6092        ND-0002-JulesPatterson.pdf
# 6093                ND-0001-Ceylon.pdf
# Name: pdf, Length: 6094, dtype: object

# %%
for s in data["pdf"]:
    s = str(s)
    if ".pdf" not in s:
        print(s)
# Out:
# 2017.02.24-Mandurah
# 2016.05.02-NZ-pdf
# 2015.10.17.b.-Hawaii. pdf
# 2015.08.19-Szsarmack
# 2015.06.30.b-Steve.pf
# 2015.06.13-Specker
# 2014.10.17-Olsson, pdf
# 2014.08.09.R-Hindley, pdf
# 2014.05.14-McLeod, pdf
# .2014.04.12.R-inflatable
# 2014.03.18.c-Borgna
# 2014.02.17.R-OneDLL
# 2014.01.26-O'Connor.pf
# 2014.01.25-Grant
# 2013.07.29.a-Gatewood
# 12.26
# 2008.07.26.a-Maui
# 1989.00.00.b-Halstead
# 1983.06.00-Starling
# 1962.08.30.b-pdf
# 1957.00.00.i-baby
# 1942.07.06-Bardolini
# 1905.07.00
# 1899.09.11.R-Guyot
# 1888.10.23.R-Croatia. Pdf
# 1863.00.00.R-Corfu
# 1823.10.07.R-Slaves
# 1788.05.10-Sydney
# 1638.00.00.R-Herbert

# %%
data["pdf"] = data["pdf"].str.replace(" ",'')
data["pdf"] = data["pdf"].str.replace("-pdf",'.pdf')
data["pdf"] = data["pdf"].str.replace(",pdf",'.pdf')
data["pdf"] = data["pdf"].str.replace(".pf",'.pdf')
data["pdf"] = data["pdf"].str.replace(".Pdf",'.pdf')

# %%
for i,s in enumerate(data["pdf"]):
    s = str(s)
    if ".pdf" not in s:
      data.loc[i,"pdf"]+= '.pdf'

# %% [markdown]
# ##(4)DATA CLEANING (ERROR DETECTION&CORRECTION MISSING VALUES)

# %%
data.isnull().sum()
# Out:
# Case Number                  0
# Date                        26
# Time                      3324
# Year                         0
# Country                     46
# Area                       412
# Location                   512
# Type                         4
# Activity                     0
# Activity Detail            537
# Name                      1752
# Sex                        571
# Age                       2737
# Injury                      28
# Fatal                       30
# Species                   4432
# Size[m]                   4019
# Investigator or Source      17
# pdf                          0
# href                         0
# dtype: int64

# %%
data['Date'] = data['Date'].ffill()

# %%
data['Time'] = data['Time'].fillna(pd.to_datetime("00:00", format='%H:%M').time())

# %%
data['Type']=data['Type'].fillna(data['Type'].mode()[0])

# %%
data['Activity Detail']=data['Activity Detail'].fillna('No detail')

# %%
data['Injury']=data['Injury'].fillna("Unknown")

# %%
data['Fatal']=data['Fatal'].fillna("Unknown")

# %%
data['Country']=data['Country'].fillna("Unknown")

# %%
data['Area']=data['Area'].fillna("Unknown")

# %%
data['Location']=data['Location'].fillna("Unknown")

# %%
data['Name']=data['Name'].fillna("Unknown")

# %%
data['Sex']=data['Sex'].fillna("Not Specified")

# %%
#try to use ml method to fill missing value in Age column
from sklearn.preprocessing import OneHotEncoder
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# Rows with missing Age (target for prediction)
missing_age = data[data['Age'].isna()]
# Rows without missing Age (training data)
non_missing_age = data[data['Age'].notna()]

# Select relevant features
features = ['Activity', 'Activity Detail', 'Type','Injury', 'Fatal']
X_train_full = non_missing_age[features]
y_train_full = non_missing_age['Age']
X_pred_full = missing_age[features]

# Encode Categorical Variables
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')  # Ensure dense output
X_train_encoded = encoder.fit_transform(X_train_full)
X_pred_encoded = encoder.transform(X_pred_full)

# %%
# Split into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train_encoded, y_train_full, test_size=0.2, random_state=42)

# %%
# Train and validate the model
model = RandomForestRegressor(n_estimators=100, random_state=42)  # Explicitly set estimators
model.fit(X_train, y_train)
y_val_pred = model.predict(X_val)

# Evaluate the model
print("Mean Squared Error:", mean_squared_error(y_val, y_val_pred))
# Out:
# Mean Squared Error: 229.9822964738409

# %%
'''
# Predict missing Age values
predicted_ages = model.predict(X_pred_encoded)

# Fill missing Age values in the original dataset
data.loc[data['Age'].isna(), 'Age'] = predicted_ages
'''
# Out:
# "\n# Predict missing Age values\npredicted_ages = model.predict(X_pred_encoded)\n\n# Fill missing Age values in the original dataset\ndata.loc[data['Age'].isna(), 'Age'] = predicted_ages\n"

# %%
data['Age']=data['Age'].fillna("Not Specified")

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# Separate rows with and without missing values in Species
missing_species = data[data['Species'].isna()]
non_missing_species = data[data['Species'].notna()]

# Select features and target
features = ['Country','Area','Location','Activity','Activity Detail','Injury','Size[m]']
X_train_all = non_missing_species[features]
y_train_all = non_missing_species['Species']
X_pred_all = missing_species[features]

# Encode categorical variables in features
encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
X_train_encoded = encoder.fit_transform(X_train_all)
X_pred_encoded = encoder.transform(X_pred_all)

# Encode the target variable (Species)
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train_all)

# Split data for training and validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_encoded, y_train_encoded, test_size=0.2, random_state=42
)

# Train a classifier
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Validate the model
y_val_pred = model.predict(X_val)
print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.5705705705705706

# %%
'''
# Predict missing Species values
predicted_species_encoded = model.predict(X_pred_encoded)

# Decode predictions back to original labels
predicted_species = label_encoder.inverse_transform(predicted_species_encoded)

# Fill missing Species values in the original dataset
data.loc[data['Species'].isna(), 'Species'] = predicted_species
'''
# Out:
# "\n# Predict missing Species values\npredicted_species_encoded = model.predict(X_pred_encoded)\n\n# Decode predictions back to original labels\npredicted_species = label_encoder.inverse_transform(predicted_species_encoded)\n\n# Fill missing Species values in the original dataset\ndata.loc[data['Species'].isna(), 'Species'] = predicted_species\n"

# %%
data['Species']=data['Species'].fillna("Unknown")

# %%
data['Size[m]'] = data['Size[m]'].fillna(data['Size[m]'].mean().round(2))

# %%
data['Investigator or Source']=data['Investigator or Source'].fillna("Unknown")

# %%
data.isnull().sum()
# Out:
# Case Number               0
# Date                      0
# Time                      0
# Year                      0
# Country                   0
# Area                      0
# Location                  0
# Type                      0
# Activity                  0
# Activity Detail           0
# Name                      0
# Sex                       0
# Age                       0
# Injury                    0
# Fatal                     0
# Species                   0
# Size[m]                   0
# Investigator or Source    0
# pdf                       0
# href                      0
# dtype: int64

# %% [markdown]
# ##(5) DATA CLEANING (ERROR DETECTION&CORRECTION OUTLIERS)

# %%
maxyear=data['Year'].max()
maxyear
# Out:
# 2017

# %%
data.loc[data['Date']>pd.Timestamp('2017-12-31'),['Case Number','Date','Year']]
# Out:
#      Case Number       Date  Year
# 91    2016.09.00 2020-09-16  2016
# 231   2015.09.00 2020-09-15  2015
# 364   2014.09.00 2020-09-14  2014
# 385   2014.08.00 2020-08-14  2014
# 579   2012.12.00 2020-12-12  2012
# ...          ...        ...   ...
# 5353  1904.09.00 2020-09-04  1904
# 5354  1904.08.00 2020-08-04  1904
# 5366  1903.07.00 2020-07-03  1903
# 5383  1902.06.00 2020-06-02  1902
# 5384  1902.04.00 2020-04-02  1902
#
# [216 rows x 3 columns]

# %%
# Check if date is greater than 2017-12-31 and replace year with Year column value
def replace_year_if_needed(row):
    if row['Date'] > pd.Timestamp('2017-12-31'):
        # Replace the year in the date with the year from the 'Year' column
        return row['Date'].replace(year=row['Year'])
    else:
        return row['Date']

data['Date'] = data.apply(replace_year_if_needed, axis=1)

# %%
#replace Year with year value in the Date column
data['Year']=data['Date'].dt.year

# %%
# Convert the Year column to integers
data['Year'] = pd.to_numeric(data['Year']).astype('Int64')

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07  00:00:00  2017  United Kingdom
# 4       2017.06.04 2017-06-04  00:00:00  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01  00:00:00  1903       Australia
# 6090       ND.0004 1903-01-01  00:00:00  1903       Australia
# 6091       ND.0003 1900-01-01  00:00:00  1900             Usa
# 6092       ND.0002 1883-01-01  00:00:00  1883          Panama
# 6093       ND.0001 1845-01-01  00:00:00  1845       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %% [markdown]
# ##(6) DATA CLEANING (DATA DEDUPLICATION)

# %%
# !pip install recordlinkage
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 11.1 MB/s eta 0:00:00
# ...

# %%
import recordlinkage

# %%
data = data.drop_duplicates()
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07  00:00:00  2017  United Kingdom
# 4       2017.06.04 2017-06-04  00:00:00  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01  00:00:00  1903       Australia
# 6090       ND.0004 1903-01-01  00:00:00  1903       Australia
# 6091       ND.0003 1900-01-01  00:00:00  1900             Usa
# 6092       ND.0002 1883-01-01  00:00:00  1883          Panama
# 6093       ND.0001 1845-01-01  00:00:00  1845       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %%
indexer = recordlinkage.index.SortedNeighbourhood(
        on='href', window=21)

candidate_links = indexer.index(data)
candidate_links
# Out:
# <ipython-input-138-0c6b04fe96dd>:1: DeprecationWarning: The argument 'on' is deprecated. Use 'left_on=...' and 'right_on=None' to simulate the behaviour of 'on'.
#   indexer = recordlinkage.index.SortedNeighbourhood(
# MultiIndex([(   9,    0),
#             (  10,    1),
#             (  11,    2),
#             (  12,    3),
#             (  13,    4),
#             (  14,    5),
#             (  15,    6),
#             (  16,    7),
#             (  17,    8),
#             (  19,   18),
#             ...
#             (6084, 5968),
#             (6085, 5973),
#             (6086, 5967),
#             (6087, 5972),
#             (6088, 5971),
#             (6089, 5970),
#             (6090,    0),
#             (6091,    1),
#             (6092,    2),
#             (6093, 5983)],
#            length=60986)

# %%
data.columns
# Out:
# Index(['Case Number', 'Date', 'Time', 'Year', 'Country', 'Area', 'Location',
#        'Type', 'Activity', 'Activity Detail', 'Name', 'Sex', 'Age', 'Injury',
#        'Fatal', 'Species', 'Size[m]', 'Investigator or Source', 'pdf', 'href'],
#       dtype='object')

# %%
compare_cl = recordlinkage.Compare()

compare_cl.exact('Case Number', 'Case Number', label='Case Number')
compare_cl.exact('Date', 'Date', label='Date')
compare_cl.exact('Time', 'Time', label='Time')
compare_cl.exact('Year', 'Year', label='Year')
compare_cl.exact('Type', 'Type', label='Type')
compare_cl.exact('Activity', 'Activity', label='Activity')
compare_cl.exact('Activity Detail', 'Activity Detail', label='Activity Detail')
compare_cl.exact('Sex', 'Sex', label='Sex')
compare_cl.exact('Age', 'Age', label='Age')
compare_cl.exact('Fatal', 'Fatal', label='Fatal')
compare_cl.exact('Species', 'Species', label='Species')
compare_cl.exact('Size[m]', 'Size[m]', label='Size[m]')

compare_cl.string('Country', 'Country', method='jarowinkler', threshold=0.9, label='Country')
compare_cl.string('Area', 'Area', method='jarowinkler', threshold=0.9, label='Area')
compare_cl.string('Location', 'Location', method='jarowinkler', threshold=0.9, label='Location')
compare_cl.string('Name', 'Name', method='jarowinkler', threshold=0.9, label='Name')
compare_cl.string('Injury', 'Injury', method='jarowinkler', threshold=0.9, label='Injury')
compare_cl.string('Investigator or Source', 'Investigator or Source', method='jarowinkler', threshold=0.9, label='Investigator or Source')
compare_cl.string('pdf', 'pdf', method='jarowinkler', threshold=0.9, label='pdf')

# %%
features = compare_cl.compute(candidate_links, data)
matches = features[features.sum(axis=1) > 15]
matches
# Out:
#            Case Number  Date  Time  Year  Type  Activity  Activity Detail  \
# 5318 5316            0     1     1     1     1         1                1
# 6060 6058            0     1     1     1     1         1                1
# 6087 6085            0     1     1     1     1         1                1
# 429  428             0     1     0     1     1         1                1
# 643  642             0     1     1     1     1         1                1
# 981  980             0     1     1     1     1         1                1
# 1068 1067            0     1     1     1     1         1                1
# 1539 1538            0     1     1     1     0         1                1
# 1927 1926            0     0     1     1     1         1                1
# 1952 1951            0     1     1     1     1         1                1
# 2039 2037            0     1     1     1     1         0                1
# 2494 2493            1     1     1     1     1         1                0
# ...

# %%
# Drop duplicates (e.g., keep the first occurrence)
duplicate_indices = matches.index.get_level_values(1)
data= data.drop(duplicate_indices)

# %%
data
# Out:
#        Case Number       Date      Time  Year         Country  \
# 0       2017.06.11 2017-06-11  08:30:00  2017       Australia
# 1     2017.06.10.b 2017-06-10  15:45:00  2017       Australia
# 2     2017.06.10.a 2017-06-10  10:00:00  2017             Usa
# 3     2017.06.07.R 2017-06-07  00:00:00  2017  United Kingdom
# 4       2017.06.04 2017-06-04  00:00:00  2017             Usa
# ...            ...        ...       ...   ...             ...
# 6089       ND.0005 1903-01-01  00:00:00  1903       Australia
# 6090       ND.0004 1903-01-01  00:00:00  1903       Australia
# 6091       ND.0003 1900-01-01  00:00:00  1900             Usa
# 6092       ND.0002 1883-01-01  00:00:00  1883          Panama
# 6093       ND.0001 1845-01-01  00:00:00  1845       Sri Lanka
#
#                    Area                                         Location  \
# 0     Western Australia                         Point Casuarina, Bunbury
# ...

# %% [markdown]
# ##DQ Assessment

# %%
for col in data.columns:
    print("DQ Assessment for "+col+":")

    DISTINCT = (data[col].nunique())
    COUNT = data[col].count()
    ROWS = len(data[col])
    UNIQUENESS = DISTINCT / ROWS
    print("UNIQUENESS: ", UNIQUENESS)

    DISTINCTNESS = DISTINCT / COUNT
    print("DISTINCTNESS: ", DISTINCTNESS)

    MAX_COUNTS = max(data[col].value_counts())
    CONSTANCY = MAX_COUNTS / COUNT
    print("CONSTANCY: ", CONSTANCY)

    COMPLETENESS = COUNT / ROWS
    print("COMPLETENESS: ", COMPLETENESS)

    print("\n\n")
# Out:
# DQ Assessment for Case Number:
# UNIQUENESS:  0.9978565539983512
# DISTINCTNESS:  0.9978565539983512
# CONSTANCY:  0.00032976092333058534
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Date:
# UNIQUENESS:  0.8314921681780709
# DISTINCTNESS:  0.8314921681780709
# CONSTANCY:  0.0018136850783182193
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Time:
# UNIQUENESS:  0.04023083264633141
# DISTINCTNESS:  0.04023083264633141
# CONSTANCY:  0.5437757625721352
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Year:
# UNIQUENESS:  0.036108821104699096
# DISTINCTNESS:  0.036108821104699096
# CONSTANCY:  0.04402308326463314
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Country:
# UNIQUENESS:  0.030667765869744436
# DISTINCTNESS:  0.030667765869744436
# CONSTANCY:  0.35449299258037925
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Area:
# UNIQUENESS:  0.12728771640560593
# DISTINCTNESS:  0.12728771640560593
# CONSTANCY:  0.16718878812860677
# COMPLETENESS:  1.0
#
#
#
# DQ Assessment for Location:
# ...

# %%
data.to_csv("/path/to/your/drive/cleaned_attacks.csv", index=False)
